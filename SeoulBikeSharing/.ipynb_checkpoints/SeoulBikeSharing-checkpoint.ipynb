# %% [markdown]
# # Seoul Bike Sharing
#
# **Attribute Information:**
#
# **-Rented Bike count:**  - Count of bikes rented at each hour, continuous numeric value<br>
# **-Hour:** Hour of the day numeric value <br>
# **-Temperature:** in Celsius numeric value <br>
# **-Humidity:** in %, numeric value <br>
# **-Windspeed:** in m/s, numeric value<br>
# **-Visibility:** in 10m, numeric value<br>
# **-Dew point temperature:** in Celsius, numeric value<br>
# **-Solar radiation:** MJ/m2, numeric value<br>
# **-Rainfall:** in mm, numeric value<br>
# **-Snowfall:** in cm, numeric value<br>
# **-Seasons:** Winter, Spring, Summer, Autumn categorical value<br>
# **-Holiday:** Holiday/No holiday binary value<br>
# **-Functional Day:** NoFunc(Non Functional Hours), Fun(Functional hours) binary value<br>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from scipy import stats
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.neighbors import KNeighborsRegressor
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics

import sys
sys.path.insert(1, '../RegressionAlgorithms/')
import linearRegression

# %% [markdown]
# ### Get the Data

# %%
data = pd.read_csv('SeoulBikeData.csv', delimiter = ',', engine='python')

# %%
data
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     01/12/2017                254     0             -5.2           37
# 1     01/12/2017                204     1             -5.5           38
# 2     01/12/2017                173     2             -6.0           39
# 3     01/12/2017                107     3             -6.2           40
# 4     01/12/2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                  2.2              2000                      -17.6
# 1                  0.8              2000                      -17.6
# 2                  1.0              2000                      -17.7
# 3                  0.9              2000                      -17.6
# 4                  2.3              2000                      -18.6
# ...                ...               ...                        ...
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 0                         0.0           0.0            0.0  Winter
# 1                         0.0           0.0            0.0  Winter
# 2                         0.0           0.0            0.0  Winter
# 3                         0.0           0.0            0.0  Winter
# 4                         0.0           0.0            0.0  Winter
# ...                       ...           ...            ...     ...
# 8755                      0.0           0.0            0.0  Autumn
# 8756                      0.0           0.0            0.0  Autumn
# 8757                      0.0           0.0            0.0  Autumn
# 8758                      0.0           0.0            0.0  Autumn
# 8759                      0.0           0.0            0.0  Autumn
#
#          Holiday Functioning Day
# 0     No Holiday             Yes
# 1     No Holiday             Yes
# 2     No Holiday             Yes
# 3     No Holiday             Yes
# 4     No Holiday             Yes
# ...          ...             ...
# 8755  No Holiday             Yes
# 8756  No Holiday             Yes
# 8757  No Holiday             Yes
# 8758  No Holiday             Yes
# 8759  No Holiday             Yes
#
# [8760 rows x 14 columns]

# %% [markdown]
# ### Basic Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 821.3+ KB

# %%
data.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# 25%            0.900000        940.000000                  -4.700000
# 50%            1.500000       1698.000000                   5.100000
# 75%            2.300000       2000.000000                  14.800000
# max            7.400000       2000.000000                  27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              8760.000000   8760.000000    8760.000000
# mean                  0.569111      0.148687       0.075068
# std                   0.868746      1.128193       0.436746
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.930000      0.000000       0.000000
# max                   3.520000     35.000000       8.800000

# %%
print(data.isnull().sum(axis=0))
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# **Rented Bike Count**

# %% [markdown]
# *Histogram of Rented Bike Count Distribution*

# %%
fig = plt.figure(figsize = (20,5))
sns.set_style('darkgrid')
bins = np.arange(0, 3540, 100).tolist()
data['Rented Bike Count'].hist(bins=bins)
plt.xticks(bins)
plt.xlabel('Rented Bike Count')
# Out:
# Text(0.5, 0, 'Rented Bike Count')

# %% [markdown]
# **Rented Bike Count vs Season**

# %%
data['Seasons'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Autumn'], dtype=object)

# %% [markdown]
# *Box plot of Rented Bike Count vs Seasons*

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Seasons'], y=data['Rented Bike Count'])
plt.show()

# %% [markdown]
# **Rented Bike Count vs Holiday**

# %% [markdown]
# *Box plot of Rented Bike Count vs Holiday*

# %%
plt.figure(figsize=(4, 6))
sns.boxplot(x=data['Holiday'], y=data['Rented Bike Count'])
plt.show()

# %% [markdown]
# **Traffic Volume vs Temperature**

# %% [markdown]
# *Plot of Rented Bike Count vs Temperature*

# %%
fig = sns.jointplot(x=data['Temperature(°C)'], y=data['Rented Bike Count'], kind='reg')

# %% [markdown]
# **Traffic Volume vs Rainfall**

# %% [markdown]
# *Plot of Rented Bike Count vs Rainfall*

# %%
fig = sns.jointplot(x=data['Rainfall(mm)'], y=data['Rented Bike Count'], kind='reg')

# %% [markdown]
# *Removing outliers*

# %%
outliers = data[(data['Rainfall(mm)'] >= 20)]
data = data.drop(outliers.index)
data.index = np.arange(1, len(data) + 1)
outliers
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 3997  16/05/2018                151    13             21.8           97
# 5034  28/06/2018                596    18             20.6           97
# 5132  02/07/2018                 61    20             23.5           97
# 6501  28/08/2018                122    21             22.9           98
# 6524  29/08/2018                 19    20             23.4           98
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 3997               2.4               682                       21.2
# 5034               0.7               222                       20.1
# 5132               0.1              1814                       22.9
# 6501               2.1              1146                       22.5
# 6524               0.6                70                       23.0
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 3997                     0.06          35.0            0.0  Spring
# 5034                     0.14          21.5            0.0  Summer
# 5132                     0.04          24.0            0.0  Summer
# 6501                     0.00          29.5            0.0  Summer
# 6524                     0.00          21.0            0.0  Summer
#
#          Holiday Functioning Day
# 3997  No Holiday             Yes
# 5034  No Holiday             Yes
# 5132  No Holiday             Yes
# 6501  No Holiday             Yes
# 6524  No Holiday             Yes

# %%
fig = sns.jointplot(x=data['Rainfall(mm)'], y=data['Rented Bike Count'], kind='reg')

# %% [markdown]
# **Traffic Volume vs Rainfall**

# %% [markdown]
# *Plot of Traffic Volume vs Wind Speed*

# %%
fig = sns.jointplot(data=data, x="Wind speed (m/s)", y="Rented Bike Count", kind='reg')

# %% [markdown]
# *Removing outliers*

# %%
outliers = data[(data['Wind speed (m/s)'] >6)]
data = data.drop(outliers.index)
data.index = np.arange(1, len(data) + 1)
outliers
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 934   08/01/2018                146    21              0.7           77
# 3135  10/04/2018                913    14             21.2           35
# 3139  10/04/2018               1805    18             19.7           52
# 3141  10/04/2018                336    20             19.1           58
# 3142  10/04/2018                133    21             17.5           70
# 6314  21/08/2018                 49     4             25.3           70
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 934                6.7               692                       -2.8
# 3135               7.4              1992                        5.1
# 3139               7.2              2000                        9.5
# 3141               6.1              2000                       10.6
# 3142               7.3              1634                       11.9
# 6314               6.9               925                       19.4
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# 934                       0.0           0.9            1.0  Winter
# 3135                      1.8           0.0            0.0  Spring
# 3139                      0.2           0.0            0.0  Spring
# 3141                      0.0           0.0            0.0  Spring
# 3142                      0.0           0.5            0.0  Spring
# 6314                      0.0           0.4            0.0  Summer
#
#          Holiday Functioning Day
# 934   No Holiday             Yes
# 3135  No Holiday             Yes
# 3139  No Holiday             Yes
# 3141  No Holiday             Yes
# 3142  No Holiday             Yes
# 6314  No Holiday             Yes

# %%
fig = sns.jointplot(data=data, x="Wind speed (m/s)", y="Rented Bike Count", kind='reg')

# %% [markdown]
# **Traffic Volume vs Snowfall**

# %% [markdown]
# *Plot of Traffic Volume vs Snowfall*

# %%
fig = plt.figure(figsize = (25,15))
ax1 = fig.add_subplot(2,3,1)
ax1.scatter(data=data, x="Snowfall (cm)", y="Rented Bike Count")

# %% [markdown]
# *Distribution only with snowy days*

# %%
data_snowy = data.loc[(data['Snowfall (cm)'] > 0)]
#data_snowy = data.loc[(data['weather_main'] == "Snow")]
data_snowy.index = np.arange(1, len(data_snowy) + 1)
data_snowy
# Out:
#            Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 1    06/12/2017                145     0             -2.8           77
# 2    06/12/2017                144     1             -3.0           79
# 3    06/12/2017                117     2             -3.0           79
# 4    06/12/2017                 78     3             -3.2           78
# 5    06/12/2017                 58     4             -3.4           75
# ..          ...                ...   ...              ...          ...
# 438  26/11/2018                115     5              2.1           88
# 439  26/11/2018                339     6              1.8           88
# 440  26/11/2018                819     7              1.7           89
# 441  26/11/2018               1524     8              2.0           84
# 442  26/11/2018                795     9              3.1           77
#
#      Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 1                 0.0               331                       -6.2
# 2                 0.0               293                       -6.1
# 3                 0.0              1862                       -6.1
# 4                 0.0              1808                       -6.4
# 5                 0.0              1982                       -7.2
# ..                ...               ...                        ...
# 438               1.4               323                        0.3
# 439               1.1               313                        0.0
# 440               1.3               295                        0.0
# 441               1.1               396                       -0.4
# 442               0.9               457                       -0.5
#
#      Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 1                       0.00           0.1            0.1  Winter  No Holiday
# 2                       0.00           0.0            0.3  Winter  No Holiday
# 3                       0.00           0.0            0.4  Winter  No Holiday
# 4                       0.00           0.2            0.4  Winter  No Holiday
# 5                       0.00           0.0            0.4  Winter  No Holiday
# ..                       ...           ...            ...     ...         ...
# 438                     0.00           0.0            0.3  Autumn  No Holiday
# 439                     0.00           0.0            0.3  Autumn  No Holiday
# 440                     0.00           0.0            0.3  Autumn  No Holiday
# 441                     0.03           0.0            0.3  Autumn  No Holiday
# 442                     0.40           0.0            0.2  Autumn  No Holiday
#
#     Functioning Day
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes
# 5               Yes
# ..              ...
# 438             Yes
# 439             Yes
# 440             Yes
# 441             Yes
# 442             Yes
#
# [442 rows x 14 columns]

# %%
fig = sns.jointplot(data=data_snowy, x="Snowfall (cm)", y="Rented Bike Count", kind='reg')

# %% [markdown]
# **Traffic Volume vs Hour**

# %% [markdown]
# *Plot of Traffic Volume vs Hour*

# %%
fig = sns.jointplot(data=data_snowy, x="Hour", y="Rented Bike Count", kind='reg')

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# *Preprocess Binary Data*

# %%
data = data.replace(to_replace=['No Holiday', 'Holiday'], value=['0', '1'])
data = data.replace(to_replace=['No', 'Yes'], value=['0', '1'])
data
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 1     01/12/2017                254     0             -5.2           37
# 2     01/12/2017                204     1             -5.5           38
# 3     01/12/2017                173     2             -6.0           39
# 4     01/12/2017                107     3             -6.2           40
# 5     01/12/2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8745  30/11/2018               1003    19              4.2           34
# 8746  30/11/2018                764    20              3.4           37
# 8747  30/11/2018                694    21              2.6           39
# 8748  30/11/2018                712    22              2.1           41
# 8749  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 1                  2.2              2000                      -17.6
# 2                  0.8              2000                      -17.6
# 3                  1.0              2000                      -17.7
# 4                  0.9              2000                      -17.6
# 5                  2.3              2000                      -18.6
# ...                ...               ...                        ...
# 8745               2.6              1894                      -10.3
# 8746               2.3              2000                       -9.9
# 8747               0.3              1968                       -9.9
# 8748               1.0              1859                       -9.8
# 8749               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons Holiday  \
# 1                         0.0           0.0            0.0  Winter       0
# 2                         0.0           0.0            0.0  Winter       0
# 3                         0.0           0.0            0.0  Winter       0
# 4                         0.0           0.0            0.0  Winter       0
# 5                         0.0           0.0            0.0  Winter       0
# ...                       ...           ...            ...     ...     ...
# 8745                      0.0           0.0            0.0  Autumn       0
# 8746                      0.0           0.0            0.0  Autumn       0
# 8747                      0.0           0.0            0.0  Autumn       0
# 8748                      0.0           0.0            0.0  Autumn       0
# 8749                      0.0           0.0            0.0  Autumn       0
#
#      Functioning Day
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# 5                  1
# ...              ...
# 8745               1
# 8746               1
# 8747               1
# 8748               1
# 8749               1
#
# [8749 rows x 14 columns]

# %% [markdown]
# *Drop Date field*

# %%
data = data.drop("Date", axis=1)
data
# Out:
#       Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# 1                   254     0             -5.2           37               2.2
# 2                   204     1             -5.5           38               0.8
# 3                   173     2             -6.0           39               1.0
# 4                   107     3             -6.2           40               0.9
# 5                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8745               1003    19              4.2           34               2.6
# 8746                764    20              3.4           37               2.3
# 8747                694    21              2.6           39               0.3
# 8748                712    22              2.1           41               1.0
# 8749                584    23              1.9           43               1.3
#
#       Visibility (10m)  Dew point temperature(°C)  Solar Radiation (MJ/m2)  \
# 1                 2000                      -17.6                      0.0
# 2                 2000                      -17.6                      0.0
# 3                 2000                      -17.7                      0.0
# 4                 2000                      -17.6                      0.0
# 5                 2000                      -18.6                      0.0
# ...                ...                        ...                      ...
# 8745              1894                      -10.3                      0.0
# 8746              2000                       -9.9                      0.0
# 8747              1968                       -9.9                      0.0
# 8748              1859                       -9.8                      0.0
# 8749              1909                       -9.3                      0.0
#
#       Rainfall(mm)  Snowfall (cm) Seasons Holiday Functioning Day
# 1              0.0            0.0  Winter       0               1
# 2              0.0            0.0  Winter       0               1
# 3              0.0            0.0  Winter       0               1
# 4              0.0            0.0  Winter       0               1
# 5              0.0            0.0  Winter       0               1
# ...            ...            ...     ...     ...             ...
# 8745           0.0            0.0  Autumn       0               1
# 8746           0.0            0.0  Autumn       0               1
# 8747           0.0            0.0  Autumn       0               1
# 8748           0.0            0.0  Autumn       0               1
# 8749           0.0            0.0  Autumn       0               1
#
# [8749 rows x 13 columns]

# %% [markdown]
# *Preprocess Non Ordinal Data*

# %%
one_hot = pd.get_dummies(data["Seasons"])
data = data.drop("Seasons",axis = 1)
data = data.join(one_hot)
data
# Out:
#       Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# 1                   254     0             -5.2           37               2.2
# 2                   204     1             -5.5           38               0.8
# 3                   173     2             -6.0           39               1.0
# 4                   107     3             -6.2           40               0.9
# 5                    78     4             -6.0           36               2.3
# ...                 ...   ...              ...          ...               ...
# 8745               1003    19              4.2           34               2.6
# 8746                764    20              3.4           37               2.3
# 8747                694    21              2.6           39               0.3
# 8748                712    22              2.1           41               1.0
# 8749                584    23              1.9           43               1.3
#
#       Visibility (10m)  Dew point temperature(°C)  Solar Radiation (MJ/m2)  \
# 1                 2000                      -17.6                      0.0
# 2                 2000                      -17.6                      0.0
# 3                 2000                      -17.7                      0.0
# 4                 2000                      -17.6                      0.0
# 5                 2000                      -18.6                      0.0
# ...                ...                        ...                      ...
# 8745              1894                      -10.3                      0.0
# 8746              2000                       -9.9                      0.0
# 8747              1968                       -9.9                      0.0
# 8748              1859                       -9.8                      0.0
# 8749              1909                       -9.3                      0.0
#
#       Rainfall(mm)  Snowfall (cm) Holiday Functioning Day  Autumn  Spring  \
# 1              0.0            0.0       0               1       0       0
# 2              0.0            0.0       0               1       0       0
# 3              0.0            0.0       0               1       0       0
# 4              0.0            0.0       0               1       0       0
# 5              0.0            0.0       0               1       0       0
# ...            ...            ...     ...             ...     ...     ...
# 8745           0.0            0.0       0               1       1       0
# 8746           0.0            0.0       0               1       1       0
# 8747           0.0            0.0       0               1       1       0
# 8748           0.0            0.0       0               1       1       0
# 8749           0.0            0.0       0               1       1       0
#
#       Summer  Winter
# 1          0       1
# 2          0       1
# 3          0       1
# 4          0       1
# 5          0       1
# ...      ...     ...
# 8745       0       0
# 8746       0       0
# 8747       0       0
# 8748       0       0
# 8749       0       0
#
# [8749 rows x 16 columns]

# %%
X = data.drop('Rented Bike Count', axis=1)
y = data['Rented Bike Count']

# %%
scaler = StandardScaler()
scaler = scaler.fit(X)
X_scaled = scaler.transform(X)

#split the data in attributes and class as well as training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ## Regression Tasks

# %% [markdown]
# ### Linear Regression

# %%
model = linear_model.LinearRegression().fit(X_train, y_train)

# Make predictions using the testing set
y_pred = model.predict(X_test)

# The coefficients
print('Coefficients: \n', model.coef_)
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))


print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Coefficients:
#  [ 2.71137948e+01  1.88939897e+01 -9.38105688e+00  2.51793686e+01
#   1.45492844e-02  8.17797675e+00 -7.59053353e+01 -7.92737953e+01
#   3.37279539e+01 -1.22973563e+02  9.16974024e+02  1.70064153e+02
#   2.15758710e+01 -1.41863151e+00 -1.90221392e+02]
# Coefficient of determination: 0.55
# Mean Absolute Error: 325.0570506456615
# Mean Squared Error: 193282.86660243425
# Root Mean Squared Error: 439.6394734352618

# %% [markdown]
# ### KNN Regression

# %%
model = KNeighborsRegressor(n_neighbors=3).fit(X_train, y_train)

# %%
# Make predictions using the testing set
y_pred = model.predict(X_test)

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))


print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Coefficient of determination: 0.47
# Mean Absolute Error: 318.184
# Mean Squared Error: 231240.4760634921
# Root Mean Squared Error: 480.8746989221746

# %%
print('==================================================')

alpha = [500, 500, 500, 500]
alphaMethod = 'const'
mu = 1
weights, score = linearRegression.linearRegression(X, y, alpha = alpha, mu = mu, convergenceCriterion = 1e-9, 
                                  lossFunction = 'MSE', alphaMethod = alphaMethod, printOutput = True)
yPred = predictLinearRegression(X, weights)
#print('yPred = ', yPred)
print('weights = ', weights)
print('score = ', score)

print('==================================================')
# Out:
# ==================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-40bac9ef59c1> in <module>
#       4 alphaMethod = 'const'
#       5 mu = 1
# ----> 6 weights, score = linearRegression.linearRegression(X, y, alpha = alpha, mu = mu, convergenceCriterion = 1e-9,
#       7                                   lossFunction = 'MSE', alphaMethod = alphaMethod, printOutput = True)
#       8
#
# ~\Desktop\machinelearning\RegressionAlgorithms\linearRegression.py in linearRegression(X, y, lossFunction, alpha, mu, convergenceCriterion, alphaMethod, printOutput, initialWeights, maxIterations)
#     113     #with the bias weight
#     114     biasCol = np.ones(NVal)
# --> 115     X.insert(loc = NVar, column = 'bias', value = biasCol)
#     116     NVar += 1
#     117
#
# c:\users\enric\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# c:\users\enric\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert bias, already exists
